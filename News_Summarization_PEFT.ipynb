# %% [markdown]
# <a href="https://colab.research.google.com/github/sarapahlevansadegh/LLM/blob/main/News_Summarization_PEFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install \
    transformers \
    datasets \
    evaluate \
    rouge_score\
    loralib \
    bitsandbytes \
    peft --quiet
